# %% [markdown]
# # Group Members:
# ## Dewansh Singh (037)
# ## Sakshi Dumbre (026)
# ## Anurag Taparia (068)
# ## Vedant Dawange (082)

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %% [markdown]
# # Step-1: Gathering Data

# %%
df=pd.read_csv("student.csv")
df.head()
# Out:
#    SIS ID  School SIS ID First Name   Last Name     Username  Middle Name  \
# 0   13001          10001        Ora       Klein       OKlein  Christopher
# 1   13002          10001     Beulah    McMillan    BMcMillan         Lynn
# 2   13003          10001   Florence       Stark       FStark        Brian
# 3   13004          10001       Noah  Gilbertson  NGilbertson          NaN
# 4   13005          10001       Erna      Parker      EParker         Troy
#
#      Status   Birthdate  Graduation Year  Quiz Duration(in min)  Grade
# 0    Active  04-02-2000           2018.0                      3     10
# 1  Inactive  11-12-1999           2018.0                      7      7
# 2  Inactive  12/19/1997           2018.0                     10      5
# 3    Active   6/20/2000           2018.0                      2      8
# 4    Active   5/17/1998           2018.0                      4      9

# %%
# let's preview the dataset

df.head(15)
# Out:
#     SIS ID  School SIS ID First Name   Last Name     Username  Middle Name  \
# 0    13001          10001        Ora       Klein       OKlein  Christopher
# 1    13002          10001     Beulah    McMillan    BMcMillan         Lynn
# 2    13003          10001   Florence       Stark       FStark        Brian
# 3    13004          10001       Noah  Gilbertson  NGilbertson          NaN
# 4    13005          10001       Erna      Parker      EParker         Troy
# 5    13006          10001     Sherry     Santana     SSantana       Thomas
# 6    13007          10001     Ronald        Lees        RLees        Grace
# 7    13008          10001    Latasha       Pratt       LPratt  Christopher
# 8    13009          10001      Misty      Thomas      MThomas         Lynn
# 9    13010          10001      Petra      Barlow      PBarlow      Francis
# 10   13011          10001     Bonnie     Hampton     PHampton       Robert
# 11   13012          10001       Dion    Matheson    DMatheson        James
# 12   13013          10001      Cesar      McCray      CMcCray        Wilma
# 13   13014          10001     Rickey      Cottle      Rcottle      Forrest
# 14   13015          10001   Fredrick     Markley     Fmarkley         Noah
#
#       Status   Birthdate  Graduation Year  Quiz Duration(in min)  Grade
# 0     Active  04-02-2000           2018.0                      3     10
# 1   Inactive  11-12-1999           2018.0                      7      7
# 2   Inactive  12/19/1997           2018.0                     10      5
# 3     Active   6/20/2000           2018.0                      2      8
# 4     Active   5/17/1998           2018.0                      4      9
# 5        NaN   8/22/1999           2018.0                      5      8
# 6     Active  05-11-1998           2018.0                      4      9
# 7   Inactive   8/13/1999           2018.0                      9      5
# 8     Active  07-06-2000           2018.0                      4      8
# 9     Active   3/19/1997           2018.0                      2      9
# 10  Inactive  04-10-1998           2018.0                      7      8
# 11  Inactive   5/17/1999              NaN                      6      5
# 12    Active   2/17/2001           2018.0                      2     10
# 13    Active  08-09-2000           2018.0                      4      9
# 14    Active   6/17/1999           2018.0                      3      8

# %%
# view dimensions of dataset

df.shape
# Out:
# (114, 11)

# %% [markdown]
# ## Statistical Method

# %%
df.describe()
# Out:
#              SIS ID  School SIS ID  Graduation Year  Quiz Duration(in min)  \
# count    114.000000     114.000000       111.000000             114.000000
# mean   13057.500000   10001.710526      2018.720721               5.701754
# std       33.052988       0.827874         0.833079               2.977585
# min    13001.000000   10001.000000      2018.000000               1.000000
# 25%    13029.250000   10001.000000      2018.000000               3.000000
# 50%    13057.500000   10001.000000      2018.000000               6.000000
# 75%    13085.750000   10002.000000      2019.000000               9.000000
# max    13114.000000   10003.000000      2020.000000              10.000000
#
#             Grade
# count  114.000000
# mean     7.815789
# std      1.962326
# min      2.000000
# 25%      7.000000
# 50%      8.000000
# 75%      9.000000
# max     10.000000

# %%
df.isnull().sum()
# Out:
# SIS ID                   0
# School SIS ID            0
# First Name               0
# Last Name                0
# Username                 0
# Middle Name              6
# Status                   2
# Birthdate                3
# Graduation Year          3
# Quiz Duration(in min)    0
# Grade                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SIS ID                 114 non-null    int64
#  1   School SIS ID          114 non-null    int64
#  2   First Name             114 non-null    object
#  3   Last Name              114 non-null    object
#  4   Username               114 non-null    object
#  5   Middle Name            108 non-null    object
#  6   Status                 112 non-null    object
#  7   Birthdate              111 non-null    object
#  8   Graduation Year        111 non-null    float64
#  9   Quiz Duration(in min)  114 non-null    int64
#  10  Grade                  114 non-null    int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 9.9+ KB

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# # Step-2: Data Preparation
# ## Data Cleaning

# %%
#invalid values
df.loc[(df['Status'] != 'Active') & (df['Status'] != 'Inactive')]
# Out:
#     SIS ID  School SIS ID First Name Last Name  Username Middle Name Status  \
# 5    13006          10001     Sherry   Santana  SSantana      Thomas    NaN
# 41   13042          10001     Blaine   Dulaney  BDulaney        Kris    NaN
#
#     Birthdate  Graduation Year  Quiz Duration(in min)  Grade
# 5   8/22/1999           2018.0                      5      8
# 41  7/27/2000           2018.0                      6      8

# %%
df= df.drop([5])
df= df.drop([41])
df.reset_index()
# Out:
#      index  SIS ID  School SIS ID First Name   Last Name     Username  \
# 0        0   13001          10001        Ora       Klein       OKlein
# 1        1   13002          10001     Beulah    McMillan    BMcMillan
# 2        2   13003          10001   Florence       Stark       FStark
# 3        3   13004          10001       Noah  Gilbertson  NGilbertson
# 4        4   13005          10001       Erna      Parker      EParker
# ..     ...     ...            ...        ...         ...          ...
# 107    109   13110          10003    Pallavi       Singh       PSingh
# 108    110   13111          10003       Arya     kashyap     AKashyap
# 109    111   13112          10003     Anandi      Chopra      AChopra
# 110    112   13113          10003     Aditya      Kapoor      AKapoor
# 111    113   13114          10003     Chris     Bumstead    CBumstead
#
#      Middle Name    Status   Birthdate  Graduation Year  \
# 0    Christopher    Active  04-02-2000           2018.0
# 1           Lynn  Inactive  11-12-1999           2018.0
# 2          Brian  Inactive  12/19/1997           2018.0
# 3            NaN    Active   6/20/2000           2018.0
# 4           Troy    Active   5/17/1998           2018.0
# ..           ...       ...         ...              ...
# 107        kumar    Active  19-05-2000           2020.0
# 108       Pandit  Inactive  12-02-2001           2020.0
# 109        Singh    Active  12-12-1999           2020.0
# 110          Raj    Active  31-01-2001           2020.0
# 111          NaN  Inactive  21-09-1999           2020.0
#
#      Quiz Duration(in min)  Grade
# 0                        3     10
# 1                        7      7
# 2                       10      5
# 3                        2      8
# 4                        4      9
# ..                     ...    ...
# 107                      2      8
# 108                      8      7
# 109                      3      8
# 110                      3      9
# 111                      8     10
#
# [112 rows x 12 columns]

# %%
df['Graduation Year'].fillna((df['Graduation Year'].mean()), inplace=True)

# %%
df.isnull().sum()
# Out:
# SIS ID                   0
# School SIS ID            0
# First Name               0
# Last Name                0
# Username                 0
# Middle Name              6
# Status                   0
# Birthdate                3
# Graduation Year          0
# Quiz Duration(in min)    0
# Grade                    0
# dtype: int64

# %% [markdown]
# # Step-3: Data Wrangling

# %%
df.head(15)
# Out:
#     SIS ID  School SIS ID First Name   Last Name     Username  Middle Name  \
# 0    13001          10001        Ora       Klein       OKlein  Christopher
# 1    13002          10001     Beulah    McMillan    BMcMillan         Lynn
# 2    13003          10001   Florence       Stark       FStark        Brian
# 3    13004          10001       Noah  Gilbertson  NGilbertson          NaN
# 4    13005          10001       Erna      Parker      EParker         Troy
# 6    13007          10001     Ronald        Lees        RLees        Grace
# 7    13008          10001    Latasha       Pratt       LPratt  Christopher
# 8    13009          10001      Misty      Thomas      MThomas         Lynn
# 9    13010          10001      Petra      Barlow      PBarlow      Francis
# 10   13011          10001     Bonnie     Hampton     PHampton       Robert
# 11   13012          10001       Dion    Matheson    DMatheson        James
# 12   13013          10001      Cesar      McCray      CMcCray        Wilma
# 13   13014          10001     Rickey      Cottle      Rcottle      Forrest
# 14   13015          10001   Fredrick     Markley     Fmarkley         Noah
# 15   13016          10001     Joshua     Bartels     Jbartels        Tracy
#
#       Status   Birthdate  Graduation Year  Quiz Duration(in min)  Grade
# 0     Active  04-02-2000      2018.000000                      3     10
# 1   Inactive  11-12-1999      2018.000000                      7      7
# 2   Inactive  12/19/1997      2018.000000                     10      5
# 3     Active   6/20/2000      2018.000000                      2      8
# 4     Active   5/17/1998      2018.000000                      4      9
# 6     Active  05-11-1998      2018.000000                      4      9
# 7   Inactive   8/13/1999      2018.000000                      9      5
# 8     Active  07-06-2000      2018.000000                      4      8
# 9     Active   3/19/1997      2018.000000                      2      9
# 10  Inactive  04-10-1998      2018.000000                      7      8
# 11  Inactive   5/17/1999      2018.733945                      6      5
# 12    Active   2/17/2001      2018.000000                      2     10
# 13    Active  08-09-2000      2018.000000                      4      9
# 14    Active   6/17/1999      2018.000000                      3      8
# 15    Active   3/19/2001      2018.000000                      4     10

# %%
df=pd.read_csv("student.csv")

# %%
df.shape
# Out:
# (114, 11)

# %%
#invalid values
df.loc[(df['Status'] != 'Active') & (df['Status'] != 'Inactive')]
# Out:
#     SIS ID  School SIS ID First Name Last Name  Username Middle Name Status  \
# 5    13006          10001     Sherry   Santana  SSantana      Thomas    NaN
# 41   13042          10001     Blaine   Dulaney  BDulaney        Kris    NaN
#
#     Birthdate  Graduation Year  Quiz Duration(in min)  Grade
# 5   8/22/1999           2018.0                      5      8
# 41  7/27/2000           2018.0                      6      8

# %%
df= df.drop([5])
df= df.drop([41])
df.reset_index()
# Out:
#      index  SIS ID  School SIS ID First Name   Last Name     Username  \
# 0        0   13001          10001        Ora       Klein       OKlein
# 1        1   13002          10001     Beulah    McMillan    BMcMillan
# 2        2   13003          10001   Florence       Stark       FStark
# 3        3   13004          10001       Noah  Gilbertson  NGilbertson
# 4        4   13005          10001       Erna      Parker      EParker
# ..     ...     ...            ...        ...         ...          ...
# 107    109   13110          10003    Pallavi       Singh       PSingh
# 108    110   13111          10003       Arya     kashyap     AKashyap
# 109    111   13112          10003     Anandi      Chopra      AChopra
# 110    112   13113          10003     Aditya      Kapoor      AKapoor
# 111    113   13114          10003     Chris     Bumstead    CBumstead
#
#      Middle Name    Status   Birthdate  Graduation Year  \
# 0    Christopher    Active  04-02-2000           2018.0
# 1           Lynn  Inactive  11-12-1999           2018.0
# 2          Brian  Inactive  12/19/1997           2018.0
# 3            NaN    Active   6/20/2000           2018.0
# 4           Troy    Active   5/17/1998           2018.0
# ..           ...       ...         ...              ...
# 107        kumar    Active  19-05-2000           2020.0
# 108       Pandit  Inactive  12-02-2001           2020.0
# 109        Singh    Active  12-12-1999           2020.0
# 110          Raj    Active  31-01-2001           2020.0
# 111          NaN  Inactive  21-09-1999           2020.0
#
#      Quiz Duration(in min)  Grade
# 0                        3     10
# 1                        7      7
# 2                       10      5
# 3                        2      8
# 4                        4      9
# ..                     ...    ...
# 107                      2      8
# 108                      8      7
# 109                      3      8
# 110                      3      9
# 111                      8     10
#
# [112 rows x 12 columns]

# %%
# view dimensions of dataset after droping the columns having invalid values

df.shape
# Out:
# (112, 11)

# %%
df = df.dropna()
df.head(15)
# Out:
#     SIS ID  School SIS ID First Name Last Name   Username  Middle Name  \
# 0    13001          10001        Ora     Klein     OKlein  Christopher
# 1    13002          10001     Beulah  McMillan  BMcMillan         Lynn
# 2    13003          10001   Florence     Stark     FStark        Brian
# 4    13005          10001       Erna    Parker    EParker         Troy
# 6    13007          10001     Ronald      Lees      RLees        Grace
# 7    13008          10001    Latasha     Pratt     LPratt  Christopher
# 8    13009          10001      Misty    Thomas    MThomas         Lynn
# 9    13010          10001      Petra    Barlow    PBarlow      Francis
# 10   13011          10001     Bonnie   Hampton   PHampton       Robert
# 12   13013          10001      Cesar    McCray    CMcCray        Wilma
# 13   13014          10001     Rickey    Cottle    Rcottle      Forrest
# 14   13015          10001   Fredrick   Markley   Fmarkley         Noah
# 15   13016          10001     Joshua   Bartels   Jbartels        Tracy
# 16   13017          10001    Maribel   Parsons   Mparsons       Delmar
# 17   13018          10001       Erma   Ballard   Eballard         Maya
#
#       Status   Birthdate  Graduation Year  Quiz Duration(in min)  Grade
# 0     Active  04-02-2000           2018.0                      3     10
# 1   Inactive  11-12-1999           2018.0                      7      7
# 2   Inactive  12/19/1997           2018.0                     10      5
# 4     Active   5/17/1998           2018.0                      4      9
# 6     Active  05-11-1998           2018.0                      4      9
# 7   Inactive   8/13/1999           2018.0                      9      5
# 8     Active  07-06-2000           2018.0                      4      8
# 9     Active   3/19/1997           2018.0                      2      9
# 10  Inactive  04-10-1998           2018.0                      7      8
# 12    Active   2/17/2001           2018.0                      2     10
# 13    Active  08-09-2000           2018.0                      4      9
# 14    Active   6/17/1999           2018.0                      3      8
# 15    Active   3/19/2001           2018.0                      4     10
# 16    Active  03-10-2000           2018.0                      3      9
# 17  Inactive  04-03-1998           2018.0                     10      6

# %%
df.groupby('Status').mean()
# Out:
#                 SIS ID  School SIS ID  Graduation Year  Quiz Duration(in min)  \
# Status
# Active    13058.122449   10001.714286      2018.714286               2.816327
# Inactive  13057.392157   10001.686275      2018.686275               8.392157
#
#              Grade
# Status
# Active    8.959184
# Inactive  6.843137

# %%
df.isnull().sum()
# Out:
# SIS ID                   0
# School SIS ID            0
# First Name               0
# Last Name                0
# Username                 0
# Middle Name              0
# Status                   0
# Birthdate                0
# Graduation Year          0
# Quiz Duration(in min)    0
# Grade                    0
# dtype: int64

# %%
df.Status.replace(('Active', 'Inactive'), (1, 0), inplace=True)
df.head(10)
# Out:
#     SIS ID  School SIS ID First Name Last Name   Username  Middle Name  \
# 0    13001          10001        Ora     Klein     OKlein  Christopher
# 1    13002          10001     Beulah  McMillan  BMcMillan         Lynn
# 2    13003          10001   Florence     Stark     FStark        Brian
# 4    13005          10001       Erna    Parker    EParker         Troy
# 6    13007          10001     Ronald      Lees      RLees        Grace
# 7    13008          10001    Latasha     Pratt     LPratt  Christopher
# 8    13009          10001      Misty    Thomas    MThomas         Lynn
# 9    13010          10001      Petra    Barlow    PBarlow      Francis
# 10   13011          10001     Bonnie   Hampton   PHampton       Robert
# 12   13013          10001      Cesar    McCray    CMcCray        Wilma
#
#     Status   Birthdate  Graduation Year  Quiz Duration(in min)  Grade
# 0        1  04-02-2000           2018.0                      3     10
# 1        0  11-12-1999           2018.0                      7      7
# 2        0  12/19/1997           2018.0                     10      5
# 4        1   5/17/1998           2018.0                      4      9
# 6        1  05-11-1998           2018.0                      4      9
# 7        0   8/13/1999           2018.0                      9      5
# 8        1  07-06-2000           2018.0                      4      8
# 9        1   3/19/1997           2018.0                      2      9
# 10       0  04-10-1998           2018.0                      7      8
# 12       1   2/17/2001           2018.0                      2     10

# %% [markdown]
# # Step-4: Analyse Data
# ## Data Visualization using several Graphical methods

# %%
df.hist(figsize=(10,8))
# Out:
# array([[<AxesSubplot:title={'center':'SIS ID'}>,
#         <AxesSubplot:title={'center':'School SIS ID'}>],
#        [<AxesSubplot:title={'center':'Status'}>,
#         <AxesSubplot:title={'center':'Graduation Year'}>],
#        [<AxesSubplot:title={'center':'Quiz Duration(in min)'}>,
#         <AxesSubplot:title={'center':'Grade'}>]], dtype=object)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, height=2.5)

# %%
fig, axes = plt.subplots(nrows=1,ncols=1)
fig.set_size_inches(5, 5)
sns.boxplot(data=df,y="Status",x="Graduation Year", palette="Oranges")
# Out:
# <AxesSubplot:xlabel='Graduation Year', ylabel='Status'>

# %% [markdown]
# **Now, as we can observe there is no Outlier's available so now our dataset is fully cleaned. Ready to Train the model using this dataset.**

# %% [markdown]
# # Step-5: Train Model

# %%
col=['Quiz Duration(in min)','Grade']
x=df[col]
y=df['Status']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
x_train.shape
# Out:
# (70, 2)

# %%
x_test.shape
# Out:
# (30, 2)

# %% [markdown]
# ## Decision Tree
#
# A decision tree is a **flowchart-like tree structure** where an internal node represents feature(or attribute), the branch represents a decision rule, and each leaf node represents the outcome. The topmost node in a decision tree is known as the root node. It learns to partition on the basis of the attribute value.  It partitions the tree in a recursive manner called recursive partitioning. **This flowchart-like structure helps you in decision making**. It can be visualized like a flowchart diagram which easily mimics human level thinking. That is why decision trees are easy to understand and interpret.

# %% [markdown]
# Another decision tree algorithm CART (Classification and Regression Tree) uses the Gini method to create split points.
#
# $$Gini(D) = 1 - \sum_{i = 1}^{m} P_i^2 $$

# %% [markdown]
# ### Building Decision Tree Model
#
# Let's create a Decision Tree Model using Scikit-learn.

# %%
def feature_imp(model):
    importance = model.feature_importances_

    for i,v in enumerate(importance):
        imp[i]=v;
        print('Feature: %0d, Score: %.5f' % (i,imp[i]))

    pyplot.bar([x for x in range(len(importance))], importance)
    pyplot.show()

# %%
from matplotlib import pyplot

clf_gini = DecisionTreeClassifier(criterion='gini',random_state=0)
clf_ginifit = clf_gini.fit(x_train,y_train)
y_pred_gini = clf_ginifit.predict(x_test)

feature_imp(clf_gini)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-4920d245325a> in <module>
#       5 y_pred_gini = clf_ginifit.predict(x_test)
#       6
# ----> 7 feature_imp(clf_gini)
#
# <ipython-input-33-8bbc20b62cb1> in feature_imp(model)
#       3
#       4     for i,v in enumerate(importance):
# ----> 5         imp[i]=v;
#       6         print('Feature: %0d, Score: %.5f' % (i,imp[i]))
#       7
#
# NameError: name 'imp' is not defined

# %% [markdown]
# ### Compute precision, recall, F-measure and support
#
# The _accuracy_ is the ratio *tp + tn = (tp + tn + fp + fn)*<br>
#
# The _precision_ is the ratio *tp / (tp + fp)* where *tp is the number of true positives* and *fp the number of false positives*. The precision is intuitively the ability of the classifier not to label as positive a sample that is negative.<br>
#
# The _recall_ is the ratio *tp / (tp + fn)* where *tp is the number of true positives* and *fn the number of false negatives*. The recall is intuitively the ability of the classifier to find all the positive samples.<br>
#
# The F-beta score can be interpreted as a weighted harmonic mean of the precision and recall, where an F-beta score reaches its best value at 1 and worst score at 0.<br>
#
# The F-beta score weights recall more than precision by a factor of beta. beta == 1.0 means recall and precision are equally important.<br>
#
# *The support is the number of occurrences of each class in y_test.*

# %% [markdown]
# # Step - 6 Test Model

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_gini))
print("Precision:",metrics.precision_score(y_test, y_pred_gini))
print("Recall:",metrics.recall_score(y_test, y_pred_gini))
print("F1 Score:",metrics.f1_score(y_test, y_pred_gini))
# Out:
# Accuracy: 0.9666666666666667
# Precision: 0.9285714285714286
# Recall: 1.0
# F1 Score: 0.962962962962963

# %% [markdown]
# **Well, we got a classification rate of 96.66%, considered as best accuracy. So no need of improvement and this shows that the dataset we got is perfectly fine. No need of pruning is required. But we will still look for some pruning methods so that still we can improve our accuracy.**

# %%
fig = plt.figure(figsize=(100,50))
DT_gini = tree.plot_tree(clf_gini, 
                   feature_names=col,  
                   class_names=['0','1'],
                   filled=True)

# %% [markdown]
# ## Optimizing Decision Tree Performance
#
# - **criterion :  optional (default=”gini”) or Choose attribute selection measure**: This parameter allows us to use the different-different attribute selection measure. Supported criteria are “gini” for the Gini index and “entropy” for the information gain.
#
#
# - **splitter : string, optional (default=”best”) or Split Strategy**: This parameter allows us to choose the split strategy. Supported strategies are “best” to choose the best split and “random” to choose the best random split.
#
#
# - **max_depth : int or None, optional (default=None) or Maximum Depth of a Tree**: The maximum depth of the tree. If None, then nodes are expanded until all the leaves contain less than min_samples_split samples. The higher value of maximum depth causes overfitting, and a lower value causes underfitting.
#
# In Scikit-learn, optimization of decision tree classifier performed by only pre-pruning. Maximum depth of the tree can be used as a control variable for pre-pruning.

# %% [markdown]
# ### Gini

# %%
clf_gini4 = DecisionTreeClassifier(criterion='gini', max_depth=4, random_state=0)
clf_fitgini4 = clf_gini4.fit(x_train,y_train)
y_pred_gini4 = clf_fitgini4.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred_gini4))
# Out:
# Accuracy: 0.9666666666666667

# %%
fig = plt.figure(figsize=(25,10))
DT_gini4 = tree.plot_tree(clf_gini4, 
                   feature_names=col,  
                   class_names=['0','1'],
                   filled=True)

# %% [markdown]
# ## Comparison of Decision Tree at different *max_depth*.

# %%
clf_gini3 = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)
clf_fitgini3 = clf_gini3.fit(x_train,y_train)
y_pred_gini3 = clf_fitgini3.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred_gini3))
# Out:
# Accuracy: 0.9666666666666667

# %%
fig = plt.figure(figsize=(15,5))
DT_gini3 = tree.plot_tree(clf_gini3, 
                   feature_names=col,  
                   class_names=['0','1'],
                   filled=True)

# %%
clf_gini2 = DecisionTreeClassifier(criterion='gini', max_depth=2, random_state=0)
clf_fitgini2 = clf_gini2.fit(x_train,y_train)
y_pred_gini2 = clf_fitgini2.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred_gini2))
# Out:
# Accuracy: 0.9666666666666667

# %%
fig = plt.figure(figsize=(7,5))
DT_gini2 = tree.plot_tree(clf_gini2, 
                   feature_names=col,  
                   class_names=['0','1'],
                   filled=True)

# %% [markdown]
# ## Entropy

# %% [markdown]
# We can plot a decision tree on the same data with max_depth=3.  Other than pre-pruning parameters like Gini used initially, now we can also try other attribute selection measure such as <b>entropy</b>.

# %%
clf_entropy = DecisionTreeClassifier(criterion='entropy',random_state=0)
clf_entropyfit = clf_entropy.fit(x_train,y_train)
y_pred_entropy = clf_entropyfit.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred_entropy))
print("Precision:",metrics.precision_score(y_test, y_pred_entropy))
print("Recall:",metrics.recall_score(y_test, y_pred_entropy))
print("F1 Score:",metrics.f1_score(y_test, y_pred_entropy))
# Out:
# Accuracy: 0.9666666666666667
# Precision: 0.9285714285714286
# Recall: 1.0
# F1 Score: 0.962962962962963

# %%
fig = plt.figure(figsize=(100,50))
DT_entropy = tree.plot_tree(clf_entropy, 
                   feature_names=col,  
                   class_names=['0','1'],
                   filled=True)

# %%
clf_entropy4 = DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=0)
clf_fitentropy4 = clf_entropy4.fit(x_train,y_train)
y_pred_entropy4 = clf_fitentropy4.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred_entropy4))
# Out:
# Accuracy: 0.9666666666666667

# %%
fig = plt.figure(figsize=(10,5))
DT_entropy4 = tree.plot_tree(clf_entropy4, 
                   feature_names=col,  
                   class_names=['0','1'],
                   filled=True)

# %%
clf_entropy3 = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
clf_fitentropy3 = clf_entropy3.fit(x_train,y_train)
y_pred_entropy3 = clf_fitentropy3.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred_entropy3))
# Out:
# Accuracy: 0.9666666666666667

# %%
fig = plt.figure(figsize=(10,5))
DT_entropy3 = tree.plot_tree(clf_entropy3, 
                   feature_names=col,  
                   class_names=['0','1'],
                   filled=True)

# %%
clf_entropy2 = DecisionTreeClassifier(criterion='entropy', max_depth=2, random_state=0)
clf_fitentropy2 = clf_entropy2.fit(x_train,y_train)
y_pred_entropy2 = clf_fitentropy2.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred_entropy2))
# Out:
# Accuracy: 0.9666666666666667

# %% [markdown]
# **As we can observe that with all possible criteria we have tried the possibilities of improving the accuracy but we are getting same accuracy this shows that without pruning we can get the best accuracy and this concludes that our dataset is perfectly refined**

# %% [markdown]
# Measure and test error to measure how many mistakes this tree has made on test data respectively.

# %%
fig = plt.figure(figsize=(7,5))
DT_entropy2 = tree.plot_tree(clf_entropy2, 
                   feature_names=col,  
                   class_names=['0','1'],
                   filled=True)

# %% [markdown]
# ### % of Error made by model

# %%
from sklearn.metrics import mean_squared_error
test_error = mean_squared_error(y_test,y_pred_gini)
print(test_error)
# Out:
# 0.03333333333333333

# %% [markdown]
# **Hence, our model is giving 96% accuracy for the collected dataset and we can conclude that with 96% of accuracy our model best fit ofr this algorithm and the attentiveness and activeness can be concluded with this model**
